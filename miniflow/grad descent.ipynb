# %%
def gradient_descent_update(x, gradx, learning_rate):
    """
    Performs a gradient descent update.
    """
    # TODO: Implement gradient descent.
    
    # Return the new value for x
    return x - learning_rate * gradx

# %%
"""
Given the starting point of any `x` gradient descent
should be able to find the minimum value of x for the
cost function `f` defined below.
"""
import random



def f(x):
    """
    Quadratic function.

    It's easy to see the minimum value of the function
    is 5 when is x=0.
    """
    return x**2 + 5


def df(x):
    """
    Derivative of `f` with respect to `x`.
    """
    return 2*x


# Random number better 0 and 10,000. Feel free to set x whatever you like.
x = random.randint(0, 10000)
# TODO: Set the learning rate
learning_rate = 0.1
epochs = 100

for i in range(epochs+1):
    cost = f(x)
    gradx = df(x)
    print("EPOCH {}: Cost = {:.3f}, x = {:.3f}".format(i, cost, gradx))
    x = gradient_descent_update(x, gradx, learning_rate)
# Out:
# EPOCH 0: Cost = 28772501.000, x = 10728.000
# EPOCH 1: Cost = 18414402.440, x = 8582.400
# EPOCH 2: Cost = 11785219.362, x = 6865.920
# EPOCH 3: Cost = 7542542.191, x = 5492.736
# EPOCH 4: Cost = 4827228.803, x = 4394.189
# EPOCH 5: Cost = 3089428.234, x = 3515.351
# EPOCH 6: Cost = 1977235.870, x = 2812.281
# EPOCH 7: Cost = 1265432.756, x = 2249.825
# EPOCH 8: Cost = 809878.764, x = 1799.860
# EPOCH 9: Cost = 518324.209, x = 1439.888
# EPOCH 10: Cost = 331729.294, x = 1151.910
# EPOCH 11: Cost = 212308.548, x = 921.528
# EPOCH 12: Cost = 135879.271, x = 737.223
# EPOCH 13: Cost = 86964.533, x = 589.778
# EPOCH 14: Cost = 55659.101, x = 471.822
# EPOCH 15: Cost = 35623.625, x = 377.458
# EPOCH 16: Cost = 22800.920, x = 301.966
# EPOCH 17: Cost = 14594.389, x = 241.573
# EPOCH 18: Cost = 9342.209, x = 193.258
# EPOCH 19: Cost = 5980.814, x = 154.607
# EPOCH 20: Cost = 3829.521, x = 123.685
# EPOCH 21: Cost = 2452.693, x = 98.948
# EPOCH 22: Cost = 1571.524, x = 79.159
# EPOCH 23: Cost = 1007.575, x = 63.327
# EPOCH 24: Cost = 646.648, x = 50.662
# EPOCH 25: Cost = 415.655, x = 40.529
# EPOCH 26: Cost = 267.819, x = 32.423
# EPOCH 27: Cost = 173.204, x = 25.939
# EPOCH 28: Cost = 112.651, x = 20.751
# EPOCH 29: Cost = 73.896, x = 16.601
# EPOCH 30: Cost = 49.094, x = 13.281
# EPOCH 31: Cost = 33.220, x = 10.624
# EPOCH 32: Cost = 23.061, x = 8.500
# EPOCH 33: Cost = 16.559, x = 6.800
# EPOCH 34: Cost = 12.398, x = 5.440
# EPOCH 35: Cost = 9.735, x = 4.352
# EPOCH 36: Cost = 8.030, x = 3.481
# EPOCH 37: Cost = 6.939, x = 2.785
# EPOCH 38: Cost = 6.241, x = 2.228
# EPOCH 39: Cost = 5.794, x = 1.782
# EPOCH 40: Cost = 5.508, x = 1.426
# EPOCH 41: Cost = 5.325, x = 1.141
# EPOCH 42: Cost = 5.208, x = 0.913
# EPOCH 43: Cost = 5.133, x = 0.730
# EPOCH 44: Cost = 5.085, x = 0.584
# EPOCH 45: Cost = 5.055, x = 0.467
# EPOCH 46: Cost = 5.035, x = 0.374
# EPOCH 47: Cost = 5.022, x = 0.299
# EPOCH 48: Cost = 5.014, x = 0.239
# EPOCH 49: Cost = 5.009, x = 0.191
# EPOCH 50: Cost = 5.006, x = 0.153
# EPOCH 51: Cost = 5.004, x = 0.122
# EPOCH 52: Cost = 5.002, x = 0.098
# EPOCH 53: Cost = 5.002, x = 0.078
# EPOCH 54: Cost = 5.001, x = 0.063
# EPOCH 55: Cost = 5.001, x = 0.050
# EPOCH 56: Cost = 5.000, x = 0.040
# EPOCH 57: Cost = 5.000, x = 0.032
# EPOCH 58: Cost = 5.000, x = 0.026
# EPOCH 59: Cost = 5.000, x = 0.021
# EPOCH 60: Cost = 5.000, x = 0.016
# EPOCH 61: Cost = 5.000, x = 0.013
# EPOCH 62: Cost = 5.000, x = 0.011
# EPOCH 63: Cost = 5.000, x = 0.008
# EPOCH 64: Cost = 5.000, x = 0.007
# EPOCH 65: Cost = 5.000, x = 0.005
# EPOCH 66: Cost = 5.000, x = 0.004
# EPOCH 67: Cost = 5.000, x = 0.003
# EPOCH 68: Cost = 5.000, x = 0.003
# EPOCH 69: Cost = 5.000, x = 0.002
# EPOCH 70: Cost = 5.000, x = 0.002
# EPOCH 71: Cost = 5.000, x = 0.001
# EPOCH 72: Cost = 5.000, x = 0.001
# EPOCH 73: Cost = 5.000, x = 0.001
# EPOCH 74: Cost = 5.000, x = 0.001
# EPOCH 75: Cost = 5.000, x = 0.001
# EPOCH 76: Cost = 5.000, x = 0.000
# EPOCH 77: Cost = 5.000, x = 0.000
# EPOCH 78: Cost = 5.000, x = 0.000
# EPOCH 79: Cost = 5.000, x = 0.000
# EPOCH 80: Cost = 5.000, x = 0.000
# EPOCH 81: Cost = 5.000, x = 0.000
# EPOCH 82: Cost = 5.000, x = 0.000
# EPOCH 83: Cost = 5.000, x = 0.000
# EPOCH 84: Cost = 5.000, x = 0.000
# EPOCH 85: Cost = 5.000, x = 0.000
# EPOCH 86: Cost = 5.000, x = 0.000
# EPOCH 87: Cost = 5.000, x = 0.000
# EPOCH 88: Cost = 5.000, x = 0.000
# EPOCH 89: Cost = 5.000, x = 0.000
# EPOCH 90: Cost = 5.000, x = 0.000
# EPOCH 91: Cost = 5.000, x = 0.000
# EPOCH 92: Cost = 5.000, x = 0.000
# EPOCH 93: Cost = 5.000, x = 0.000
# EPOCH 94: Cost = 5.000, x = 0.000
# EPOCH 95: Cost = 5.000, x = 0.000
# EPOCH 96: Cost = 5.000, x = 0.000
# EPOCH 97: Cost = 5.000, x = 0.000
# EPOCH 98: Cost = 5.000, x = 0.000
# EPOCH 99: Cost = 5.000, x = 0.000
# EPOCH 100: Cost = 5.000, x = 0.000
