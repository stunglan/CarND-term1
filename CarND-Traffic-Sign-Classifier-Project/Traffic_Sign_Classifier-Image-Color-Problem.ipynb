# %% [markdown]
# # Self-Driving Car Engineer Nanodegree
#
# ## Deep Learning
#
#
#
# In this notebook try to find the cause of why image convertion changes color

# %%
# %matplotlib inline
# imports
import pickle
import random
import math

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import matplotlib.image as mpimg

# %% [markdown]
# ---
# ## Step 0: Load The Data

# %%
# Load pickled data


# TODO: Fill this in based on where you saved the training and testing data

training_file = 'train.p'
testing_file = 'test.p'

with open(training_file, mode='rb') as f:
    train = pickle.load(f)
with open(testing_file, mode='rb') as f:
    test = pickle.load(f)
    
X_train, y_train = train['features'], train['labels']
X_test, y_test = test['features'], test['labels']

signs = pd.read_csv('./signnames.csv')

# %%
### Data exploration visualization goes here.
### Feel free to use as many code cells as needed.
## added som more cells

index = random.randint(0, len(X_train))
image = X_train[index].squeeze()

plt.figure(figsize=(1,1))
plt.imshow(image)
print(y_train[index])

# a random set of images
sample_signs = random.sample(range(1,len(y_train)), 20)


def plot_signs(sample_signs,x,y,signs):
    
    plt.figure(figsize = (12,8))
    gs1 = gridspec.GridSpec(4,int(math.ceil(len(sample_signs)/4)))
    gs1.update(wspace=0.01, hspace=0.02) 

    for i in range(len(sample_signs)):
        # i = i + 1 # grid spec indexes from 0
        ax1 = plt.subplot(gs1[i])
        plt.axis('on')
        ax1.set_xticklabels([])
        ax1.set_yticklabels([])
        ax1.set_aspect('equal')
        plt.imshow(x[sample_signs[i]])
        plt.text(2,4,signs.iloc[y[sample_signs[i]]]['SignName'],color='k',backgroundcolor='y')
        plt.axis('off')
    plt.show()

plot_signs(sample_signs,X_train,y_train,signs)
# Out:
# 17

# %%
mpimg.imsave('deerjump.png',X_train[3])

# %%
### pinpoint error


Xn = [] 

newimage = mpimg.imread('deerjump.png') # 32,32,3 an np.array image series

Xn.append(newimage)
            
Xn = np.array(Xn,dtype = np.float32)


plt.subplot(2, 1, 1)
plt.imshow(newimage) # shows expected colours
plt.subplot(2, 1, 2)
plt.imshow(Xn[0]) # shows "inverted" colours


print('X_train.shape: ',Xn.shape)

print('isequiv: ',np.array_equiv(newimage, Xn[0])) # True

print('newimage:')
print(newimage[5,5,:])
print('Xn:')
print(Xn[0][5,5,:])
print('$%&&')


#plot_signs(sample_signs,Xn_train,yn_train,signs)
# Out:
# X_train.shape:  (1, 32, 32, 4)
# isequiv:  True
# newimage:
# [ 0.60392159  0.26274511  0.24313726  1.        ]
# Xn:
# [ 0.60392159  0.26274511  0.24313726  1.        ]
# $%&&
